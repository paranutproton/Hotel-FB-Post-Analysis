# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
result = pd.DataFrame()
for i in range (1,7,1) :
    df = pd.read_csv('./drive/MyDrive/Try/'+str(i)+'.csv')
    result = pd.concat([result,df], ignore_index=True, sort=False)
print(result)
result.to_csv('./drive/MyDrive/Try/2021_fb_data.csv', encoding='utf-8')
# Out:
#                              โพสต์ ID  \
# 0                                 NaN
# 1     207105956480810_946167162574682
# 2     207105956480810_945499449308120
# 3     207105956480810_935587070299358
# 4     207105956480810_934385390419526
# ..                                ...
# 142  207105956480810_1196471574210905
# 143  207105956480810_1196959200828809
# 144  207105956480810_1194140737777322
# 145  207105956480810_1189640221560707
# 146  207105956480810_1188086715049391
#
#                                              ลิงก์ถาวร  \
# 0                                                  NaN
# 1    https://www.facebook.com/tubtimsiamriverkwai/p...
# 2    https://www.facebook.com/tubtimsiamriverkwai/p...
# 3    https://www.facebook.com/tubtimsiamriverkwai/p...
# 4    https://www.facebook.com/tubtimsiamriverkwai/p...
# ..                                                 ...
# 142  https://www.facebook.com/tubtimsiamriverkwai/p...
# ...

# %%
result
# Out:
#                              โพสต์ ID  \
# 0                                 NaN
# 1     207105956480810_946167162574682
# 2     207105956480810_945499449308120
# 3     207105956480810_935587070299358
# 4     207105956480810_934385390419526
# ..                                ...
# 142  207105956480810_1196471574210905
# 143  207105956480810_1196959200828809
# 144  207105956480810_1194140737777322
# 145  207105956480810_1189640221560707
# 146  207105956480810_1188086715049391
#
#                                              ลิงก์ถาวร  \
# 0                                                  NaN
# 1    https://www.facebook.com/tubtimsiamriverkwai/p...
# 2    https://www.facebook.com/tubtimsiamriverkwai/p...
# 3    https://www.facebook.com/tubtimsiamriverkwai/p...
# 4    https://www.facebook.com/tubtimsiamriverkwai/p...
# ..                                                 ...
# 142  https://www.facebook.com/tubtimsiamriverkwai/p...
# ...
