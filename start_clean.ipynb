# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('./drive/MyDrive/Try/2020-2022_fb_data.csv')
df
# Out:
#      Unnamed: 0                          โพสต์ ID  \
# 0             0                               NaN
# 1             1   207105956480810_946167162574682
# 2             2   207105956480810_945499449308120
# 3             3   207105956480810_935587070299358
# 4             4   207105956480810_934385390419526
# ..          ...                               ...
# 142         142  207105956480810_1196471574210905
# 143         143  207105956480810_1196959200828809
# 144         144  207105956480810_1194140737777322
# 145         145  207105956480810_1189640221560707
# 146         146  207105956480810_1188086715049391
#
#                                              ลิงก์ถาวร  \
# 0                                                  NaN
# 1    https://www.facebook.com/tubtimsiamriverkwai/p...
# 2    https://www.facebook.com/tubtimsiamriverkwai/p...
# 3    https://www.facebook.com/tubtimsiamriverkwai/p...
# 4    https://www.facebook.com/tubtimsiamriverkwai/p...
# ...

# %%
new_column_names = []
for col_name in df.columns:
  new_col_name = ''
  for char in col_name:
    if (char.isspace()):
        char = '_'
    elif (not char.isalnum()):
        continue
    new_col_name = new_col_name + char.lower()
  new_column_names.append(new_col_name)

# %%
print(new_column_names)
# Out:
# ['unnamed_0', 'โพสต_id', 'ลงกถาวร', 'โพสตขอความ', 'ประเภท', 'ประเทศ', 'ภาษา', 'ทโพสต', 'การกำหนดเปาหมายกลมผเขาชม', 'lifetime_post_total_reach', 'lifetime_post_organic_reach', 'lifetime_post_paid_reach', 'lifetime_post_total_impressions', 'lifetime_engaged_users', 'lifetime_organic_video_views', 'lifetime_average_time_video_viewed', 'lifetime_post_stories']

# %%
df.columns = new_column_names

# %%
df.head(2)
# Out:
#    unnamed_0                          โพสต_id  \
# 0          0                              NaN
# 1          1  207105956480810_946167162574682
#
#                                              ลงกถาวร  \
# 0                                                NaN
# 1  https://www.facebook.com/tubtimsiamriverkwai/p...
#
#                                           โพสตขอความ ประเภท  ประเทศ  ภาษา  \
# 0                                                NaN    NaN     NaN   NaN
# 1  🌦ช่วงปลายฝนต้นหนาว เป็นช่วงเวลาดีๆในการได้พักผ...  Photo     NaN   NaN
#
#                     ทโพสต การกำหนดเปาหมายกลมผเขาชม  \
# 0                     NaN                      NaN
# 1  10/30/2020 02:36:00 AM
#
#                            lifetime_post_total_reach  \
# 0  Lifetime: The number of people who had your Pa...
# 1                                               4434
#
#                          lifetime_post_organic_reach  \
# 0  Lifetime: The number of people who had your Pa...
# ...

# %%
df.rename(columns={'โพสต_id	':'post_id','ทโพสต':'post_date'}, inplace=True)

# %%
df.columns
# Out:
# Index(['unnamed_0', 'โพสต_id', 'ลงกถาวร', 'โพสตขอความ', 'ประเภท', 'ประเทศ',
#        'ภาษา', 'post_date', 'การกำหนดเปาหมายกลมผเขาชม',
#        'lifetime_post_total_reach', 'lifetime_post_organic_reach',
#        'lifetime_post_paid_reach', 'lifetime_post_total_impressions',
#        'lifetime_engaged_users', 'lifetime_organic_video_views',
#        'lifetime_average_time_video_viewed', 'lifetime_post_stories'],
#       dtype='object')

# %%
df.rename(columns={'โพสต_id':'post_id','ลงกถาวร':'link','โพสตขอความ':'text','ประเภท':'type','การกำหนดเปาหมายกลมผเขาชม':'goal'}, inplace=True)

# %%
df.head(4)
# Out:
#    unnamed_0                          post_id  \
# 0          0                              NaN
# 1          1  207105956480810_946167162574682
# 2          2  207105956480810_945499449308120
# 3          3  207105956480810_935587070299358
#
#                                                 link  \
# 0                                                NaN
# 1  https://www.facebook.com/tubtimsiamriverkwai/p...
# 2  https://www.facebook.com/tubtimsiamriverkwai/p...
# 3  https://www.facebook.com/tubtimsiamriverkwai/p...
#
#                                                 text   type  ประเทศ  ภาษา  \
# 0                                                NaN    NaN     NaN   NaN
# 1  🌦ช่วงปลายฝนต้นหนาว เป็นช่วงเวลาดีๆในการได้พักผ...  Photo     NaN   NaN
# 2  🌺 31 ตุลาคม 63 วันลอยกระทงปีนี้ 🌺\n\nไม่อยากลอ...  Photo     NaN   NaN
# 3  วันนี้แอดมีข่าวดีมาบอก!!👍\n\nโครงการ “เราเที่ย...  Photo     NaN   NaN
#
#                 post_date goal  \
# 0                     NaN  NaN
# ...

# %%
df.loc[df['post_id'].isna()]
# Out:
#      unnamed_0 post_id link text type  ประเทศ  ภาษา post_date goal  \
# 0            0     NaN  NaN  NaN  NaN     NaN   NaN       NaN  NaN
# 37          37     NaN  NaN  NaN  NaN     NaN   NaN       NaN  NaN
# 59          59     NaN  NaN  NaN  NaN     NaN   NaN       NaN  NaN
# 83          83     NaN  NaN  NaN  NaN     NaN   NaN       NaN  NaN
# 111        111     NaN  NaN  NaN  NaN     NaN   NaN       NaN  NaN
# 136        136     NaN  NaN  NaN  NaN     NaN   NaN       NaN  NaN
#
#                              lifetime_post_total_reach  \
# 0    Lifetime: The number of people who had your Pa...
# 37   Lifetime: The number of people who had your Pa...
# 59   Lifetime: The number of people who had your Pa...
# 83   Lifetime: The number of people who had your Pa...
# 111  Lifetime: The number of people who had your Pa...
# 136  Lifetime: The number of people who had your Pa...
#
#                            lifetime_post_organic_reach  \
# ...

# %%
#df.drop([0,37,59,83,111,136])
mask = np.array(df[df['post_id'].isna()].index)
df.drop(mask,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 141 entries, 1 to 146
# Data columns (total 17 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   unnamed_0                           141 non-null    int64
#  1   post_id                             141 non-null    object
#  2   link                                141 non-null    object
#  3   text                                140 non-null    object
#  4   type                                140 non-null    object
#  5   ประเทศ                              0 non-null      float64
#  6   ภาษา                                0 non-null      float64
#  7   post_date                           141 non-null    object
#  8   goal                                141 non-null    object
#  9   lifetime_post_total_reach           141 non-null    object
#  10  lifetime_post_organic_reach         141 non-null    object
# ...

# %%
df = df.convert_dtypes()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 141 entries, 1 to 146
# Data columns (total 17 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   unnamed_0                           141 non-null    Int64
#  1   post_id                             141 non-null    string
#  2   link                                141 non-null    string
#  3   text                                140 non-null    string
#  4   type                                140 non-null    string
#  5   ประเทศ                              0 non-null      Int64
#  6   ภาษา                                0 non-null      Int64
#  7   post_date                           141 non-null    string
#  8   goal                                141 non-null    string
#  9   lifetime_post_total_reach           141 non-null    string
#  10  lifetime_post_organic_reach         141 non-null    string
# ...

# %%
df['post_date']
# Out:
# 1      10/30/2020 02:36:00 AM
# 2      10/26/2020 09:47:04 PM
# 3      10/14/2020 06:49:21 PM
# 4      10/13/2020 12:11:05 AM
# 5      10/07/2020 04:39:09 AM
#                 ...
# 142    11/25/2021 08:55:26 PM
# 143    11/24/2021 01:52:49 AM
# 144    11/19/2021 11:25:03 AM
# 145    11/12/2021 06:39:04 PM
# 146    11/10/2021 01:57:55 AM
# Name: post_date, Length: 141, dtype: string

# %%
df['post_date']= pd.to_datetime(df['post_date'], format='%m/%d/%Y %I:%M:%S %p')

# %%
df['post_date']
# Out:
# 1     2020-10-30 02:36:00
# 2     2020-10-26 21:47:04
# 3     2020-10-14 18:49:21
# 4     2020-10-13 00:11:05
# 5     2020-10-07 04:39:09
#               ...
# 142   2021-11-25 20:55:26
# 143   2021-11-24 01:52:49
# 144   2021-11-19 11:25:03
# 145   2021-11-12 18:39:04
# 146   2021-11-10 01:57:55
# Name: post_date, Length: 141, dtype: datetime64[ns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 141 entries, 1 to 146
# Data columns (total 17 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   unnamed_0                           141 non-null    Int64
#  1   post_id                             141 non-null    string
#  2   link                                141 non-null    string
#  3   text                                140 non-null    string
#  4   type                                140 non-null    string
#  5   ประเทศ                              0 non-null      Int64
#  6   ภาษา                                0 non-null      Int64
#  7   post_date                           141 non-null    datetime64[ns]
#  8   goal                                141 non-null    string
#  9   lifetime_post_total_reach           141 non-null    string
#  10  lifetime_post_organic_reach         141 non-null    string
# ...

# %%
df.sort_values(by='post_date',ascending=True,inplace=True)

# %%
df.reset_index(drop=True, inplace=True)

# %%
df['post_date'].nunique()
# Out:
# 141

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 141 entries, 0 to 140
# Data columns (total 17 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   unnamed_0                           141 non-null    Int64
#  1   post_id                             141 non-null    string
#  2   link                                141 non-null    string
#  3   text                                140 non-null    string
#  4   type                                140 non-null    string
#  5   ประเทศ                              0 non-null      Int64
#  6   ภาษา                                0 non-null      Int64
#  7   post_date                           141 non-null    datetime64[ns]
#  8   goal                                141 non-null    string
#  9   lifetime_post_total_reach           141 non-null    string
#  10  lifetime_post_organic_reach         141 non-null    string
# ...

# %%
df = df.astype({'lifetime_post_total_reach': 'int64',
    'lifetime_post_organic_reach': 'int64',
    'lifetime_post_paid_reach': 'int64',
    'lifetime_post_total_impressions': 'int64',
    'lifetime_engaged_users': 'int64',
    'lifetime_organic_video_views': 'int64',
    'lifetime_average_time_video_viewed': 'int64',
    'lifetime_post_stories': 'int64'})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 141 entries, 0 to 140
# Data columns (total 17 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   unnamed_0                           141 non-null    Int64
#  1   post_id                             141 non-null    string
#  2   link                                141 non-null    string
#  3   text                                140 non-null    string
#  4   type                                140 non-null    string
#  5   ประเทศ                              0 non-null      Int64
#  6   ภาษา                                0 non-null      Int64
#  7   post_date                           141 non-null    datetime64[ns]
#  8   goal                                141 non-null    string
#  9   lifetime_post_total_reach           141 non-null    int64
#  10  lifetime_post_organic_reach         141 non-null    int64
# ...

# %%
df.head()
# Out:
#    unnamed_0                          post_id  \
# 0         58  207105956480810_727669017757832
# 1         57  207105956480810_734554663735934
# 2         56  207105956480810_738154086709325
# 3         55  207105956480810_739047393286661
# 4         54  207105956480810_744399029418164
#
#                                                 link  \
# 0  https://www.facebook.com/tubtimsiamriverkwai/p...
# 1  https://www.facebook.com/tubtimsiamriverkwai/p...
# 2  https://www.facebook.com/tubtimsiamriverkwai/p...
# 3  https://www.facebook.com/tubtimsiamriverkwai/p...
# 4  https://www.facebook.com/tubtimsiamriverkwai/p...
#
#                                                 text   type  ประเทศ  ภาษา  \
# 0  สวัสดีปีใหม่ 2563 นะคะ😍
#
# ขอให้ทุกๆท่านมีสุขภาพ...  Photo    <NA>  <NA>
# 1  💖🤵🏻👰🏻💖ทางรีสอร์ทขอขอบคุณ คุณนพและคุณปังปอนด์ ท...  Photo    <NA>  <NA>
# 2  เปิดลายแทงจุดเช็คอินใหม่ “เขาแหลมสกายวอล์ค” ทา...  Photo    <NA>  <NA>
# 3  💥 Flash sales ฉลองปี 2020😊 💥
#
# ...

# %%
df.drop(columns=['unnamed_0','ประเทศ','ภาษา'], inplace=True)
df
# Out:
#                               post_id  \
# 0     207105956480810_727669017757832
# 1     207105956480810_734554663735934
# 2     207105956480810_738154086709325
# 3     207105956480810_739047393286661
# 4     207105956480810_744399029418164
# ..                                ...
# 136  207105956480810_1200635753794487
# 137  207105956480810_1201362623721800
# 138  207105956480810_1205746206616775
# 139  207105956480810_1210741179450611
# 140  207105956480810_1210729629451766
#
#                                                   link  \
# 0    https://www.facebook.com/tubtimsiamriverkwai/p...
# 1    https://www.facebook.com/tubtimsiamriverkwai/p...
# 2    https://www.facebook.com/tubtimsiamriverkwai/p...
# 3    https://www.facebook.com/tubtimsiamriverkwai/p...
# 4    https://www.facebook.com/tubtimsiamriverkwai/p...
# ..                                                 ...
# 136  https://www.facebook.com/tubtimsiamriverkwai/p...
# ...

# %%
df.groupby('post_date')['lifetime_post_total_reach'].sum().plot(kind='line',figsize =(16,6),grid=True)

# %%
df[(df['post_date'] >= '2021-06-1') & (df['post_date'] < '2021-07-31')]
# Out:
#                               post_id  \
# 107  207105956480810_1087514271773303
# 108  207105956480810_1088617601662970
# 109  207105956480810_1089969861527744
# 110  207105956480810_1092955907895806
# 111  207105956480810_1096649294193134
# 112  207105956480810_1102763290248401
# 113  207105956480810_1111698516021545
# 114  207105956480810_1114971782360885
# 115  207105956480810_1120625018462228
#
#                                                   link  \
# 107  https://www.facebook.com/tubtimsiamriverkwai/p...
# 108  https://www.facebook.com/tubtimsiamriverkwai/p...
# 109  https://www.facebook.com/tubtimsiamriverkwai/p...
# 110  https://www.facebook.com/tubtimsiamriverkwai/p...
# 111  https://www.facebook.com/tubtimsiamriverkwai/p...
# 112  https://www.facebook.com/tubtimsiamriverkwai/p...
# 113  https://www.facebook.com/tubtimsiamriverkwai/p...
# 114  https://www.facebook.com/tubtimsiamriverkwai/p...
# 115  https://www.facebook.com/tubtimsiamriverkwai/p...
#
# ...

# %%
df.iloc[108]['link']
# Out:
# 'https://www.facebook.com/tubtimsiamriverkwai/posts/pfbid027pDA8aJG1KBP66YRYPXkcb61KaQHJV8Mkp9ZmGXwComQ5aTyd3QD4jx8jonMeMwnl'

# %%
df.groupby('post_date')[['lifetime_post_total_reach','lifetime_post_organic_reach','lifetime_post_paid_reach']].sum().plot(kind='line',subplots=True,figsize =(16,6),grid=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f086725eb10>,
# ...
#       dtype=object)

# %%
#df.groupby('post_date')['lifetime_post_total_reach'].cumsum().plot(kind='line')
df['cum_total_reach'] = df['lifetime_post_total_reach'].cumsum()
df['cum_organic_reach'] = df['lifetime_post_organic_reach'].cumsum()
df['cum_paid_reach'] = df['lifetime_post_paid_reach'].cumsum()

# %%
df.plot(x='post_date',y=['cum_total_reach','cum_organic_reach','cum_paid_reach'],figsize =(16,6),grid=True,ylabel='*10^6')

# %%
df[['lifetime_post_total_reach','lifetime_post_organic_reach','lifetime_post_paid_reach']].plot(kind='box',showfliers=False, figsize =(16,6))

# %%
df.sort_values(by=['lifetime_post_organic_reach'],ascending=False).head(10)
# Out:
#                               post_id  \
# 36    207105956480810_877804766077589
# 108  207105956480810_1088617601662970
# 129  207105956480810_1166653637192699
# 99   207105956480810_1050469315477799
# 32    207105956480810_856858591505540
# 140  207105956480810_1210729629451766
# 128  207105956480810_1164821724042557
# 136  207105956480810_1200635753794487
# 125  207105956480810_1157640514760678
# 121  207105956480810_1146263539231709
#
#                                                   link  \
# 36   https://www.facebook.com/tubtimsiamriverkwai/p...
# 108  https://www.facebook.com/tubtimsiamriverkwai/p...
# 129  https://www.facebook.com/tubtimsiamriverkwai/p...
# 99   https://www.facebook.com/tubtimsiamriverkwai/p...
# 32   https://www.facebook.com/tubtimsiamriverkwai/p...
# 140  https://www.facebook.com/tubtimsiamriverkwai/p...
# 128  https://www.facebook.com/tubtimsiamriverkwai/p...
# 136  https://www.facebook.com/tubtimsiamriverkwai/p...
# ...

# %%
df.sort_values(by=['lifetime_post_paid_reach'],ascending=False)
# Out:
#                               post_id  \
# 108  207105956480810_1088617601662970
# 129  207105956480810_1166653637192699
# 36    207105956480810_877804766077589
# 99   207105956480810_1050469315477799
# 9     207105956480810_760305331160867
# ..                                ...
# 42    207105956480810_918056322052433
# 41    207105956480810_912784959246236
# 40    207105956480810_905919336599465
# 39    207105956480810_902141610310571
# 140  207105956480810_1210729629451766
#
#                                                   link  \
# 108  https://www.facebook.com/tubtimsiamriverkwai/p...
# 129  https://www.facebook.com/tubtimsiamriverkwai/p...
# 36   https://www.facebook.com/tubtimsiamriverkwai/p...
# 99   https://www.facebook.com/tubtimsiamriverkwai/p...
# 9    https://www.facebook.com/tubtimsiamriverkwai/p...
# ..                                                 ...
# 42   https://www.facebook.com/tubtimsiamriverkwai/p...
# ...

# %%
df_no_paid = df[(df['lifetime_post_organic_reach'] > 0) & (df['lifetime_post_paid_reach'] == 0)].sort_values(by=['post_date'],ascending=True)
df_no_paid.reset_index(drop=True, inplace=True)

# %%
df_no_paid.groupby('post_date')['lifetime_post_organic_reach'].sum().plot(kind='line',subplots=True,figsize =(16,6),grid=True,title='lifetime_post_organic_reach_NO_PAID')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f0866997510>],
#       dtype=object)

# %%
df.groupby('post_date')['lifetime_post_organic_reach'].sum().plot(kind='line',figsize =(16,6),grid=True,title='lifetime_post_organic_reach_WITH_PAID')

# %%
df_no_paid.sort_values(by=['lifetime_post_organic_reach'],ascending=False).head(15)
# Out:
#                               post_id  \
# 30    207105956480810_856858591505540
# 132  207105956480810_1210729629451766
# 121  207105956480810_1164821724042557
# 128  207105956480810_1200635753794487
# 118  207105956480810_1157640514760678
# 114  207105956480810_1146263539231709
# 120  207105956480810_1162230467635016
# 124  207105956480810_1189640221560707
# 123  207105956480810_1188086715049391
# 122  207105956480810_1177917859399610
# 129  207105956480810_1201362623721800
# 131  207105956480810_1210741179450611
# 126  207105956480810_1196959200828809
# 130  207105956480810_1205746206616775
# 113  207105956480810_1146258222565574
#
#                                                   link  \
# 30   https://www.facebook.com/tubtimsiamriverkwai/p...
# 132  https://www.facebook.com/tubtimsiamriverkwai/p...
# 121  https://www.facebook.com/tubtimsiamriverkwai/p...
# 128  https://www.facebook.com/tubtimsiamriverkwai/p...
# 118  https://www.facebook.com/tubtimsiamriverkwai/p...
# ...

# %%
df_no_paid.iloc[30]['link'],df_no_paid.iloc[132]['link'],df_no_paid.iloc[121]['link']
# Out:
# ('https://www.facebook.com/tubtimsiamriverkwai/posts/pfbid0YyocnTEK6Zs3wh1RP2SozZinMJP2YUcXAKkeJ4sZkqCZaJgMXT9JzbrWrFwZKYFWl',
#  'https://www.facebook.com/tubtimsiamriverkwai/posts/pfbid02kyoKvqFrATaLGqRNZ5cBic9eXBVq1pnGPqvJorDQ5Ceq4a4EJjbxt1LAKBxEptopl',
#  'https://www.facebook.com/tubtimsiamriverkwai/posts/pfbid02abHeRx2LBtRa6VkiQe7LZCBveaxx5Qwp37V8xLpjdxWgCdWniVt7UHv8NQwU7Bxhl')

# %%
df_no_paid['type'].value_counts()
# Out:
# Photo          116
# Status           7
# Video            5
# Link             3
# SharedVideo      1
# Name: type, dtype: Int64

# %%
df_no_paid[df_no_paid['type']=='Video'].sort_values(by='lifetime_post_organic_reach',ascending=False)
# Out:
#                               post_id  \
# 30    207105956480810_856858591505540
# 120  207105956480810_1162230467635016
# 122  207105956480810_1177917859399610
# 125  207105956480810_1194140737777322
# 94    207105956480810_462657748215554
#
#                                                   link  \
# 30   https://www.facebook.com/tubtimsiamriverkwai/p...
# 120  https://www.facebook.com/tubtimsiamriverkwai/p...
# 122  https://www.facebook.com/tubtimsiamriverkwai/p...
# 125  https://www.facebook.com/tubtimsiamriverkwai/p...
# 94   https://www.facebook.com/tubtimsiamriverkwai/v...
#
#                                                   text   type  \
# 30   🍰🍲เริ่มต้นวันใหม่ด้วยอาหารเช้าที่หลากหลาย ห้อง...  Video
# 120  🙏บรรยากาศตักบาตร ท่ามกลางสายหมอกเช้านี้
#
# #หมอก...  Video
# 122  🏊‍♀️ ว่ายน้ำพักผ่อนสบายๆ…ความสุขของเด็กๆและครอ...  Video
# 125  🎍บรรยากาศวันลอยกระทง 2564😊
# .
# #ลอยกระทง #กาญจนบุรี  Video
# 94   พาทัวร์ชมบรรยากาศรีสอร์ท
# บรรยากาศเป็นแบบไหน? ...  Video
#
# ...

# %%
df_no_paid['str_date'] = df_no_paid['post_date'].dt.strftime('%a %y-%m-%d')
df_no_paid.head()
# Out:
#                            post_id  \
# 0  207105956480810_727669017757832
# 1  207105956480810_734554663735934
# 2  207105956480810_738154086709325
# 3  207105956480810_739047393286661
# 4  207105956480810_744399029418164
#
#                                                 link  \
# 0  https://www.facebook.com/tubtimsiamriverkwai/p...
# 1  https://www.facebook.com/tubtimsiamriverkwai/p...
# 2  https://www.facebook.com/tubtimsiamriverkwai/p...
# 3  https://www.facebook.com/tubtimsiamriverkwai/p...
# 4  https://www.facebook.com/tubtimsiamriverkwai/p...
#
#                                                 text   type  \
# 0  สวัสดีปีใหม่ 2563 นะคะ😍
#
# ขอให้ทุกๆท่านมีสุขภาพ...  Photo
# 1  💖🤵🏻👰🏻💖ทางรีสอร์ทขอขอบคุณ คุณนพและคุณปังปอนด์ ท...  Photo
# 2  เปิดลายแทงจุดเช็คอินใหม่ “เขาแหลมสกายวอล์ค” ทา...  Photo
# 3  💥 Flash sales ฉลองปี 2020😊 💥
#
# ขับรถเที่ยวสบายๆ...  Photo
# 4  🎋🧧ซินเจียยู่อี่ ซินนี้ฮวดใช้💰🎋
# ตรุษจีนปีนี้ พา...  Photo
#
# ...

# %%
df_no_paid['dow'] = df_no_paid['post_date'].dt.dayofweek.astype(str) + '_' + df_no_paid['str_date'].str[:3]
df_no_paid.head()
# Out:
#                            post_id  \
# 0  207105956480810_727669017757832
# 1  207105956480810_734554663735934
# 2  207105956480810_738154086709325
# 3  207105956480810_739047393286661
# 4  207105956480810_744399029418164
#
#                                                 link  \
# 0  https://www.facebook.com/tubtimsiamriverkwai/p...
# 1  https://www.facebook.com/tubtimsiamriverkwai/p...
# 2  https://www.facebook.com/tubtimsiamriverkwai/p...
# 3  https://www.facebook.com/tubtimsiamriverkwai/p...
# 4  https://www.facebook.com/tubtimsiamriverkwai/p...
#
#                                                 text   type  \
# 0  สวัสดีปีใหม่ 2563 นะคะ😍
#
# ขอให้ทุกๆท่านมีสุขภาพ...  Photo
# 1  💖🤵🏻👰🏻💖ทางรีสอร์ทขอขอบคุณ คุณนพและคุณปังปอนด์ ท...  Photo
# 2  เปิดลายแทงจุดเช็คอินใหม่ “เขาแหลมสกายวอล์ค” ทา...  Photo
# 3  💥 Flash sales ฉลองปี 2020😊 💥
#
# ขับรถเที่ยวสบายๆ...  Photo
# 4  🎋🧧ซินเจียยู่อี่ ซินนี้ฮวดใช้💰🎋
# ตรุษจีนปีนี้ พา...  Photo
#
# ...

# %%
df_no_paid.groupby(['type','dow'])['lifetime_post_organic_reach'].sum().unstack().fillna(0).astype(int)
# Out:
# dow          0_Mon   1_Tue   2_Wed   3_Thu  4_Fri  5_Sat  6_Sun
# type
# Link             0    4425   10605       0      0      0   1005
# Photo        81591  118192  108346  111090  73795  36657  53228
# SharedVideo      0       0       0       0      0      0  10015
# Status           0       0       0       0      0   4704   1289
# Video            0    5265   16516   12697   9809      0  11523

# %%
df_no_paid['hour'] = df_no_paid['post_date'].dt.hour
mean_likes_by_dow_time = pd.pivot_table(df_no_paid, index='hour', columns='dow',values='lifetime_post_organic_reach',aggfunc='mean', fill_value=0).astype(int)
mean_likes_by_dow_time
# Out:
# dow   0_Mon  1_Tue  2_Wed  3_Thu  4_Fri  5_Sat  6_Sun
# hour
# 0         0   2970      0      0    551      0      0
# 1         0  10134   8821   8267   7526   4704   6857
# 2      2558      0   4730    907   4434   6641   1005
# 3      3037   5475   2437   2683   2071      0   2374
# 4         0  14444   5370      0      0      0    214
# 5         0    872   6695   4053      0      0      0
# 6         0  13078      0      0      0      0      0
# 9         0    319      0   3739      0      0      0
# 11        0      0      0      0   9809      0      0
# 14        0      0  10605      0      0      0      0
# 16     5230   4806      0      0      0      0   4735
# 17        0      0  12737      0      0      0      0
# 18        0      0   5734   3968   8843      0    686
# 19     4683   7369   4061   9060      0   3009      0
# 20        0   5549   2858   6322   3893   3350   4714
# 21     5356   5309  16516   7693      0   5607   7567
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
fig, ax = plt.subplots(figsize=(8,6))
ax = sns.heatmap(mean_likes_by_dow_time, ax=ax, annot=True, fmt='d')
ax.set_title('Mean lifetime_post_organic_reach by Date of Week and Time of Day')
plt.show()
### TIME is in California Pacific Time Zone

# %%
df_no_paid.loc[4]['link']
# Out:
# 'https://www.facebook.com/tubtimsiamriverkwai/posts/pfbid0gkqomUHXGJiHxcK266pNbKZcJqJWcvMrnDzGTtQing67xcrwJDNDF1sth1ua5Qkyl'

# %%
df_no_paid.head()
# Out:
#                            post_id  \
# 0  207105956480810_727669017757832
# 1  207105956480810_734554663735934
# 2  207105956480810_738154086709325
# 3  207105956480810_739047393286661
# 4  207105956480810_744399029418164
#
#                                                 link  \
# 0  https://www.facebook.com/tubtimsiamriverkwai/p...
# 1  https://www.facebook.com/tubtimsiamriverkwai/p...
# 2  https://www.facebook.com/tubtimsiamriverkwai/p...
# 3  https://www.facebook.com/tubtimsiamriverkwai/p...
# 4  https://www.facebook.com/tubtimsiamriverkwai/p...
#
#                                                 text   type  \
# 0  สวัสดีปีใหม่ 2563 นะคะ😍
#
# ขอให้ทุกๆท่านมีสุขภาพ...  Photo
# 1  💖🤵🏻👰🏻💖ทางรีสอร์ทขอขอบคุณ คุณนพและคุณปังปอนด์ ท...  Photo
# 2  เปิดลายแทงจุดเช็คอินใหม่ “เขาแหลมสกายวอล์ค” ทา...  Photo
# 3  💥 Flash sales ฉลองปี 2020😊 💥
#
# ขับรถเที่ยวสบายๆ...  Photo
# 4  🎋🧧ซินเจียยู่อี่ ซินนี้ฮวดใช้💰🎋
# ตรุษจีนปีนี้ พา...  Photo
#
# ...

# %%
df_no_paid['n_hashtags']=df['text'].str.count('#')
df_no_paid
# Out:
#                               post_id  \
# 0     207105956480810_727669017757832
# 1     207105956480810_734554663735934
# 2     207105956480810_738154086709325
# 3     207105956480810_739047393286661
# 4     207105956480810_744399029418164
# ..                                ...
# 128  207105956480810_1200635753794487
# 129  207105956480810_1201362623721800
# 130  207105956480810_1205746206616775
# 131  207105956480810_1210741179450611
# 132  207105956480810_1210729629451766
#
#                                                   link  \
# 0    https://www.facebook.com/tubtimsiamriverkwai/p...
# 1    https://www.facebook.com/tubtimsiamriverkwai/p...
# 2    https://www.facebook.com/tubtimsiamriverkwai/p...
# 3    https://www.facebook.com/tubtimsiamriverkwai/p...
# 4    https://www.facebook.com/tubtimsiamriverkwai/p...
# ..                                                 ...
# 128  https://www.facebook.com/tubtimsiamriverkwai/p...
# ...

# %%
df_no_paid.plot(x='n_hashtags',y='lifetime_post_organic_reach',kind='scatter')
#NO correlation

# %%
df_no_paid['n_chars'] = df_no_paid['text'].str.len()
df_no_paid
# Out:
#                               post_id  \
# 0     207105956480810_727669017757832
# 1     207105956480810_734554663735934
# 2     207105956480810_738154086709325
# 3     207105956480810_739047393286661
# 4     207105956480810_744399029418164
# ..                                ...
# 128  207105956480810_1200635753794487
# 129  207105956480810_1201362623721800
# 130  207105956480810_1205746206616775
# 131  207105956480810_1210741179450611
# 132  207105956480810_1210729629451766
#
#                                                   link  \
# 0    https://www.facebook.com/tubtimsiamriverkwai/p...
# 1    https://www.facebook.com/tubtimsiamriverkwai/p...
# 2    https://www.facebook.com/tubtimsiamriverkwai/p...
# 3    https://www.facebook.com/tubtimsiamriverkwai/p...
# 4    https://www.facebook.com/tubtimsiamriverkwai/p...
# ..                                                 ...
# 128  https://www.facebook.com/tubtimsiamriverkwai/p...
# ...

# %%
df_no_paid.plot(x='n_chars',y='lifetime_post_organic_reach',kind='scatter')

# %%
df_no_paid.groupby('post_date')[['lifetime_engaged_users','lifetime_post_organic_reach']].sum().plot(kind='line',subplots=True,figsize =(16,6),grid=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f08561c8f10>,
# ...
#       dtype=object)

# %%
df_no_paid.groupby('post_date')['lifetime_engaged_users'].sum().plot(kind='line',figsize =(16,6),grid=True,title='lifetime_post_organic_reach_WITH_PAID')

# %%
import plotly.express as px
fig = px.line(df_no_paid, x="post_date", y="lifetime_engaged_users", title='Skooldio FB Post Likes Progression (2020)')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_no_paid['lifetime_engaged_users'].plot(kind='box',showfliers=False, figsize =(16,6))

# %%
df_no_paid.sort_values(by=['lifetime_engaged_users'],ascending = False)['lifetime_engaged_users']
# Out:
# 132    612
# 129    588
# 120    430
# 30     414
# 15     326
#       ...
# 29       1
# 3        1
# 41       0
# 44       0
# 28       0
# Name: lifetime_engaged_users, Length: 133, dtype: int64

# %%
df_no_paid.iloc[132]['link'],df_no_paid.iloc[129]['link'],df_no_paid.iloc[120]['link']
# Out:
# ('https://www.facebook.com/tubtimsiamriverkwai/posts/pfbid02kyoKvqFrATaLGqRNZ5cBic9eXBVq1pnGPqvJorDQ5Ceq4a4EJjbxt1LAKBxEptopl',
#  'https://www.facebook.com/tubtimsiamriverkwai/posts/pfbid0h3YxmiQ99LSMF4qxyeU38CFnyXTRaoabZN7tAcTcjJdCqyuxFcCzKbKVfbdtzBzol',
#  'https://www.facebook.com/tubtimsiamriverkwai/posts/pfbid0D24ufyHVTBEFou9i6nGXhBf4cswYmNuSLHvZ9ahmUdbR3Ff8XZSz1HmqKTcQFd3dl')

# %%
df_no_paid[['lifetime_engaged_users','lifetime_post_organic_reach']].corr()
# Out:
#                              lifetime_engaged_users  \
# lifetime_engaged_users                     1.000000
# lifetime_post_organic_reach                0.753537
#
#                              lifetime_post_organic_reach
# lifetime_engaged_users                          0.753537
# lifetime_post_organic_reach                     1.000000
